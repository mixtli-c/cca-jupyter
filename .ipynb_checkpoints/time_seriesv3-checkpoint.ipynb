# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
import h5py
import glob
import copy
import datetime as dt

# %%
### Inicio de la parte que requiere modificacion por el usuario

# nombre del sitio, extension, tipo de fuente (e.g. LtCO2 o target)
# para generar titulo del grafico y nombre de archivo de salida
location_name = 'Altz'
size = '15km'
sourcetype = 'OCO3'
plotname = location_name + ' ' + size + ' ' + sourcetype
filename = location_name + '_' + size + '_' + sourcetype

# direccion de los archivos HDF de entrada y salidda 
# nombre semilla de los archivos (e.g. mexico_oco3_target, o mexico_oco3_early)
path_hdfin = "d:\\CCA\\NASAGESDISC\\OCO3L2Lite\\mexico3\\"
seedname = 'mexico_oco3_lite_'
path_hdfout = "D:\\CCA\\NASAGESDISC\\OCO3L2Lite\\timeseries2020\\"
path_plotout = "D:\\CCA\\NASAGESDISC\\OCO3L2Lite\\timeseries2020\\"
name_hdfout = path_hdfout + filename + '.h5'
name_plotout = path_plotout + filename + '.png'

# nombre en el archivo HDF de las variables de latitud (y), longitud (x), y de interes (z)
# aqui se incluye el nombre de POSIX (tepoch) por si se llegase a cambiar
# NOTA, estos valores tienen que ser escalares, vectores (e.g. columna de co2) van a generar error
latname = 'lat'
lonname = 'lon'
zname = '/xco2'
epochname = 'tepoch'

# inicializacion de las condiciones : anyo, mes (o meses), punto de interes (lat y lon), tamanyo de grid deseado
years = [2017,2018,2019,2020]
months = np.arange(1,13)                           # np.arange(n,m) genera un arreglo con primer elemento n y ultimo m-1
latpoint = 19.1187                               # latitud del punto de interes
lonpoint = -98.6552                                 # longitud del punto de interes
radiuskm = 15                                  # radio del grid en km
gridsize = radiuskm/110.567                  # tamanyo del grid en fraccion de grados

### Fin de la parte que requiere moddificacion por el usuario

# %%
# Esta seccion genera una matriz 3x3x2 con las coordenadas +- 1 grado de latitud y longitud de las seccion del punto de interes
# e.g para 19N-98W genera un grid 9x9 que va de 20N-99W a 18N-97W

# Dependiendo del punto de interes y del tamanyo del area en fraccion de grados; una, varias, o todas las celdas del grid 9x9 
# entraran en los datos que se buscan

# Se genera un filtro para construir las diferentes etiquetas xN-yW para accesar a las carpetas del archivo HDF y obtener los
# datos 

# latitud y longitud maxima y minima
grid_max_lat = latpoint + gridsize
grid_min_lat = latpoint - gridsize
grid_max_lon = lonpoint - gridsize
grid_min_lon = lonpoint + gridsize

# convertir los float a integer
gridlat = int(latpoint)
gridlon = int(lonpoint)
gridmaxlat = int(grid_max_lat)
gridminlat = int(grid_min_lat)
gridmaxlon = int(grid_max_lon)
gridminlon = int(grid_min_lon)

# vectores de latitud y longitud
latvector = [gridlat-1,gridlat,gridlat+1]
lonvector = [gridlon+1,gridlon,gridlon-1]

# matriz 3x3x2 con los grids individuales de latitud y longitud
# creada a mano, quiza haya una forma de hacerla menos explicita?
grid9x9 = np.array([[[latvector[2],lonvector[2]],[latvector[2],lonvector[1]],[latvector[2],lonvector[0]]], \
                   [[latvector[1],lonvector[2]],[latvector[1],lonvector[1]],[latvector[1],lonvector[0]]], \
                   [[latvector[0],lonvector[2]],[latvector[0],lonvector[1]],[latvector[0],lonvector[0]]]])

# filtro para seleccionar los grids que cubre el punto central con el tamanyo de grid
mask = (grid9x9[:,:,0] >= gridminlat) & (grid9x9[:,:,0] <= gridmaxlat) & (grid9x9[:,:,1] <= gridminlon) & (grid9x9[:,:,1] >= gridmaxlon)

# %%
# contadores inevitables
cont = 0                              # para saber que hacer si la matriz de datos ya se creo o no

# %%
# testing
#print(gridmaxlat,gridminlat,gridmaxlon,gridminlon)
#
#print(mask)
#
#print(grid9x9[mask])
#
#for row in grid9x9[mask]:
#    gridname = '%iN%iW' % (int(row[0]),int(row[1]))
#    print(gridname)

# %%
# algoritmo para generar la matriz de todos los datos en el grid 1x1 de los diferentes hdf
# este arrojara la matriz que despues se filtrara para hacer las series de tiempo
for year in years:
    for month in months:
        h5name = "%i%02i.h5" %(year,month)
        h5file = path_hdfin + seedname + h5name
        print('Intentando con el archivo: ', h5file)
        
        try:
            data = h5py.File(h5file,'r')
            
            for coords in grid9x9[mask]:
                
                gridname = '%iN%iW' % (coords[0],coords[1])
                #print(gridname)
                
                try:
                    # Toma las coordenadas del gris 1x1 y filtra los datos en una matriz temporal
                    # genera una matriz permanente que acumula los datos de las diferentes fechas
                    # y los diferentes gris
                    
                    lat = data[gridname][latname]
                    lon = data[gridname][lonname]
                    
                    # condiciones para reducir el tamaño del grid alrededor del punto seleccionado y obtener datos dentro de ese nuevo grid
                    distances2=np.array((lat-latpoint)**2+np.cos(np.pi/180.0*latpoint)**2*(lon-lonpoint)**2)
                    gridcond=(gridsize**2 > distances2)

                    #filterdata = datos[gridname][gridcond]

                    mat = data[gridname][gridcond]
        
        
                    if cont == 0:
                        # copia la matriz temporal en una permanente
                        # esto solo se debe usar si no existe ya la matriz permanente
                        datos=copy.copy(mat)
            
                    else:
                        # concatena los datos de la matriz temporal en la permanente
                        # esto solo se debe usar si ya existe la matriz permanente
                        datos=np.concatenate((mat,datos),axis=0)
                    
                    cont = cont + 1
                    print('Matriz temporal:', mat.shape)
                    print('Datos filtrados: ', datos.shape)
                    print('Datos fuente: ', data[gridname].shape)
                
                except:
                    print('no hay datos para %iN%iW' %(coords[0],coords[1]))
                    continue
                           
            data.close()
                    
        except:
            print('no hay datos para %i-%02i' %(year,month))
            continue
# Out:
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201701.h5
# no hay datos para 2017-01
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201702.h5
# no hay datos para 2017-02
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201703.h5
# no hay datos para 2017-03
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201704.h5
# no hay datos para 2017-04
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201705.h5
# no hay datos para 2017-05
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201706.h5
# no hay datos para 2017-06
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201707.h5
# no hay datos para 2017-07
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201708.h5
# no hay datos para 2017-08
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201709.h5
# no hay datos para 2017-09
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201710.h5
# no hay datos para 2017-10
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201711.h5
# no hay datos para 2017-11
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201712.h5
# no hay datos para 2017-12
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201801.h5
# no hay datos para 2018-01
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201802.h5
# no hay datos para 2018-02
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201803.h5
# no hay datos para 2018-03
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201804.h5
# no hay datos para 2018-04
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201805.h5
# no hay datos para 2018-05
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201806.h5
# no hay datos para 2018-06
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201807.h5
# no hay datos para 2018-07
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201808.h5
# no hay datos para 2018-08
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201809.h5
# no hay datos para 2018-09
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201810.h5
# no hay datos para 2018-10
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201811.h5
# no hay datos para 2018-11
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201812.h5
# no hay datos para 2018-12
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201901.h5
# no hay datos para 2019-01
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201902.h5
# no hay datos para 2019-02
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201903.h5
# no hay datos para 2019-03
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201904.h5
# no hay datos para 2019-04
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201905.h5
# no hay datos para 2019-05
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201906.h5
# no hay datos para 2019-06
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201907.h5
# no hay datos para 2019-07
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201908.h5
# Matriz temporal: (0,)
# Datos filtrados:  (0,)
# Datos fuente:  (8,)
# Matriz temporal: (0,)
# Datos filtrados:  (0,)
# Datos fuente:  (19,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201909.h5
# Matriz temporal: (0,)
# Datos filtrados:  (0,)
# Datos fuente:  (30,)
# no hay datos para 18N-98W
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201910.h5
# no hay datos para 19N-98W
# no hay datos para 18N-98W
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201911.h5
# no hay datos para 19N-98W
# no hay datos para 18N-98W
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_201912.h5
# no hay datos para 19N-98W
# Matriz temporal: (0,)
# Datos filtrados:  (0,)
# Datos fuente:  (73,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202001.h5
# Matriz temporal: (9,)
# Datos filtrados:  (9,)
# Datos fuente:  (64,)
# Matriz temporal: (0,)
# Datos filtrados:  (9,)
# Datos fuente:  (5,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202002.h5
# Matriz temporal: (1,)
# Datos filtrados:  (10,)
# Datos fuente:  (298,)
# Matriz temporal: (0,)
# Datos filtrados:  (10,)
# Datos fuente:  (5,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202003.h5
# Matriz temporal: (7,)
# Datos filtrados:  (17,)
# Datos fuente:  (328,)
# Matriz temporal: (0,)
# Datos filtrados:  (17,)
# Datos fuente:  (9,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202004.h5
# Matriz temporal: (0,)
# Datos filtrados:  (17,)
# Datos fuente:  (383,)
# no hay datos para 18N-98W
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202005.h5
# Matriz temporal: (0,)
# Datos filtrados:  (17,)
# Datos fuente:  (438,)
# Matriz temporal: (0,)
# Datos filtrados:  (17,)
# Datos fuente:  (13,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202006.h5
# Matriz temporal: (35,)
# Datos filtrados:  (52,)
# Datos fuente:  (476,)
# Matriz temporal: (0,)
# Datos filtrados:  (52,)
# Datos fuente:  (275,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202007.h5
# Matriz temporal: (0,)
# Datos filtrados:  (52,)
# Datos fuente:  (59,)
# no hay datos para 18N-98W
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202008.h5
# Matriz temporal: (2,)
# Datos filtrados:  (54,)
# Datos fuente:  (290,)
# Matriz temporal: (0,)
# Datos filtrados:  (54,)
# Datos fuente:  (204,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202009.h5
# Matriz temporal: (0,)
# Datos filtrados:  (54,)
# Datos fuente:  (26,)
# Matriz temporal: (0,)
# Datos filtrados:  (54,)
# Datos fuente:  (17,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202010.h5
# Matriz temporal: (5,)
# Datos filtrados:  (59,)
# Datos fuente:  (280,)
# Matriz temporal: (0,)
# Datos filtrados:  (59,)
# Datos fuente:  (59,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202011.h5
# Matriz temporal: (1,)
# Datos filtrados:  (60,)
# Datos fuente:  (148,)
# Matriz temporal: (0,)
# Datos filtrados:  (60,)
# Datos fuente:  (74,)
# Intentando con el archivo:  d:\CCA\NASAGESDISC\OCO3L2Lite\mexico3\mexico_oco3_lite_202012.h5
# Matriz temporal: (0,)
# Datos filtrados:  (60,)
# Datos fuente:  (48,)
# no hay datos para 18N-98W

# %%
fh5=h5py.File(name_hdfout,'w')
dset=fh5.create_dataset(filename,data=datos,maxshape=(None,))
fh5.flush()
fh5.close()

# %%
# grafica una serie de tiempo sencilla con los datos filtrados por las condiciones
time = np.array([dt.datetime.utcfromtimestamp(ele) for ele in datos[epochname]]) 
locator = mdates.AutoDateLocator()
formatter = mdates.DateFormatter('%d/%m')
fig, ax = plt.subplots()
plt.plot_date(time,datos[zname]) 
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_tick_params(rotation=30, labelsize=10)
plt.xlabel('Date')
plt.ylabel(zname)
plt.title(plotname)
plt.tight_layout()
plt.savefig(name_plotout)
plt.show()

# %%
# testing
# print(datos[:,0])
#print(datos[:,1])
#print(datos[:,2])

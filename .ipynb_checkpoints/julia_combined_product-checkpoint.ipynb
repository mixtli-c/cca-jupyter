# %%
6*7
# Out:
# 42

# %%
using Winston
plot(rand(100))
# Out:
# ┌ Info: Precompiling Winston [bd07be1c-e76f-5ff0-9c0b-f51ef45303c6]
# └ @ Base loading.jl:1278
# FramedPlot(...)

# %%
import Pkg; Pkg.add("Winston")
# Out:
#    Updating registry at `C:\Users\muss\.julia\registries\General`
#    Updating registry at `C:\Users\muss\.julia\registries\JuliaComputingRegistry`
#   Resolving package versions...
# Updating `C:\Users\muss\.julia\environments\JuliaPro_v1.5.2-1\Project.toml`
#   [bd07be1c] + Winston v0.15.1
# Updating `C:\Users\muss\.julia\environments\JuliaPro_v1.5.2-1\Manifest.toml`
#   [7b86fcea] + ATK_jll v2.34.1+5
#   [56f22d72] + Artifacts v1.3.0
#   [6e34b625] + Bzip2_jll v1.0.6+5
#   [159f3aea] + Cairo v1.0.5
#   [83423d85] + Cairo_jll v1.16.0+6
#   [ee1fde0b] + Dbus_jll v1.12.16+3
#   [2e619515] + Expat_jll v2.2.7+6
#   [a3f928ae] + Fontconfig_jll v2.13.1+14
#   [d7e528f0] + FreeType2_jll v2.10.1+5
#   [559328eb] + FriBidi_jll v1.0.5+6
#   [77ec8976] + GTK3_jll v3.24.11+5
#   [78b55507] + Gettext_jll v0.20.1+7
#   [7746bdde] + Glib_jll v2.59.0+4
#   [75302f13] + Graphene_jll v1.10.0+2
#   [a2bd30eb] + Graphics v1.1.0
#   [3b182d85] + Graphite2_jll v1.3.13+4
#   [42e2da0e] + Grisu v1.0.0
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import pandas as pd
import glob
import h5py
import netCDF4 as nc
from scipy import stats
from pytz import all_timezones

# %%
def MJDtoDT(mjd2k):
    """Take the modified julian day from 2000, convert to seconds, add to seconds since jan 1,00:00:00.00"""
    t0 = dt.datetime.utcfromtimestamp(0.0)
    t2k = dt.datetime(2000,1,1,0,0,0)
    t2k = (t2k-t0).total_seconds()
    tmjd = mjd2k * 86400
    date = dt.datetime.utcfromtimestamp(t2k+tmjd)
    return date

# %%
ds = nc.Dataset('test.hdf')

# %%
mjd2k = ds["DATETIME"][()]
o3column = ds["O3.COLUMN_ABSORPTION.SOLAR"][()]
# Out:
# <ipython-input-16-c2e7fa86893f>:1: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mjd2k = ds["DATETIME"][()]
# <ipython-input-16-c2e7fa86893f>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   o3column = ds["O3.COLUMN_ABSORPTION.SOLAR"][()]

# %%
time = np.array([MJDtoDT(ele) for ele in mjd2k])
print(time)
# Out:
# [datetime.datetime(2012, 10, 26, 20, 48, 33, 120000)
#  datetime.datetime(2012, 10, 26, 21, 2, 13, 920000)
#  datetime.datetime(2012, 10, 26, 21, 16, 56, 64000) ...
#  datetime.datetime(2021, 7, 24, 18, 16, 50, 880000)
#  datetime.datetime(2021, 7, 24, 19, 50, 19, 968000)
#  datetime.datetime(2021, 7, 24, 19, 57, 46, 656000)]

# %%
plt.plot(time,o3column)

# %%
tempdict = {'time': time, 'o3column': o3column}
smalldf = pd.DataFrame(data=tempdict)
smalldf
# Out:
#                         time  o3column
# 0    2012-10-26 20:48:33.120  6.756701
# 1    2012-10-26 21:02:13.920  6.717759
# 2    2012-10-26 21:16:56.064  6.727473
# 3    2012-11-16 13:29:04.704  6.483526
# 4    2012-11-16 13:36:58.176  6.505157
# ...                      ...       ...
# 4635 2021-07-24 16:28:47.424  7.946076
# 4636 2021-07-24 16:36:13.248  7.922451
# 4637 2021-07-24 18:16:50.880  7.949151
# 4638 2021-07-24 19:50:19.968  7.943056
# 4639 2021-07-24 19:57:46.656  7.947200
#
# [4640 rows x 2 columns]

# %%
#localization of dataframe so that datetime is UTC and not naive
timeutc=smalldf.time.dt.tz_localize('Etc/UTC')
timelocal=timeutc.dt.tz_convert('Etc/GMT+6')
smalldflocal = smalldf.assign(time=timelocal)
#make timeseries
smallts = smalldflocal.set_index('time')
#make mean and stdevs
smalltsmean_hr = smallts.o3column.groupby(smallts.index.hour).mean()
smalltsstd_hr = smallts.o3column.groupby(smallts.index.hour).std()
smalltsmean_mnt = smallts.o3column.groupby(smallts.index.month).mean()
smalltsstd_mnt = smallts.o3column.groupby(smallts.index.month).std()
smalltsmean_yr = smallts.o3column.groupby(smallts.index.year).mean()
smalltsstd_yr = smallts.o3column.groupby(smallts.index.year).std()

# %%
## pyplot plotting SINGLE
# PANDONIA = loc, MERRA2 = merra, FTIR = ftir
# varname format = ts + source + mean/std + hourly(none)/monthly(mt) + total(none)/trop/strat 
# e.g. tsmerrameanmttrop

# Variable definition
x1 = smalltsmean_hr.index
y1 = smalltsmean_hr
err1 = smalltsstd_hr
x2 = smalltsmean_mnt.index
y2 = smalltsmean_mnt
err2 = smalltsstd_mnt
x3 = smalltsmean_yr.index 
y3 = smalltsmean_yr
err3 = smalltsstd_yr

### INITIALIZATION
fig, ax1 = plt.subplots(figsize=(14, 8))

## line and stdev
#ax1.plot(x1, y1, '-b')
#ax1.fill_between(x1, y1-err1, y1+err1,alpha=.25, edgecolor='#3F7F4C', facecolor='b',linewidth=0)
#ax1.plot(x2, y2, '-g')
#ax1.fill_between(x2, y2-err2, y2+err2,alpha=.25, edgecolor='#3F7F4C', facecolor='g',linewidth=0)
ax1.plot(x3, y3, '-r')
ax1.fill_between(x3, y3-err3, y3+err3,alpha=.25, edgecolor='#3F7F4C', facecolor='r',linewidth=0)

## LABEL, marker and errorbar
#ax1.errorbar(x1, y1, yerr=err1, fmt='bo', label='Pandonia Altzomoni (total)')
#ax1.errorbar(x2, y2, yerr=err2, fmt='go', label='MERRA2 (tropospheric)')
ax1.errorbar(x3, y3, yerr=err3, fmt='ro', label='FTIR (tropospheric)')

## Formatting 
#ax1.set_xticks(np.arange(0,24))
ax1.set_xlabel('Year',size=14)
ax1.set_ylabel('Emolecule/cm$^2$',size=14)
ax1.set_title("Ozone profile",size=16)
#ax1.legend(fontsize=12, loc='upper left')
ax1.tick_params(labelsize=12)

## SAVEFIG
#plt.savefig('D:\\CCA\\PANDONIA\\diurnalO3PanAltzMERRA.png')

# %%
## pyplot plotting MULTI
# PANDONIA = loc, MERRA2 = merra, FTIR = ftir
# varname format = ts + source + mean/std + hourly(none)/monthly(mt) + total(none)/trop/strat 
# e.g. tsmerrameanmttrop

# Variable definition
x1 = smalltsmean_hr.index
y1 = smalltsmean_hr
err1 = smalltsstd_hr
x2 = smalltsmean_mnt.index
y2 = smalltsmean_mnt
err2 = smalltsstd_mnt
x3 = smalltsmean_yr.index 
y3 = smalltsmean_yr
err3 = smalltsstd_yr

plt.figure(figsize=(14,24)) 

ax1 = plt.subplot(3, 1, 1) 
## line and stdev
ax1.plot(x1, y1, '-b')
ax1.fill_between(x1, y1-err1, y1+err1,alpha=.25, edgecolor='#3F7F4C', facecolor='b',linewidth=0)
## LABEL, marker and errorbar
ax1.errorbar(x1, y1, yerr=err1, fmt='bo', label='')
## Formatting 
#ax1.set_xticks(np.arange(0,24))
ax1.set_xlabel('Hour',size=14)
ax1.set_ylabel('Emolecule/cm$^2$',size=14)
ax1.set_title("Ozone profile (Altzomoni)",size=16)
#ax1.legend(fontsize=12, loc='upper left')
ax1.tick_params(labelsize=12)

ax2 = plt.subplot(3, 1, 2) 
## line and stdev
ax2.plot(x2, y2, '-g')
ax2.fill_between(x2, y2-err2, y2+err2,alpha=.25, edgecolor='#3F7F4C', facecolor='g',linewidth=0)
## LABEL, marker and errorbar
ax2.errorbar(x2, y2, yerr=err2, fmt='go', label='')
## Formatting 
#ax2.set_xticks(np.arange(0,24))
ax2.set_xlabel('Month',size=14)
ax2.set_ylabel('Emolecule/cm$^2$',size=14)
#ax2.set_title("Ozone profile",size=16)
#ax2.legend(fontsize=12, loc='upper left')
ax2.tick_params(labelsize=12)

ax3 = plt.subplot(3, 1, 3) 
## line and stdev
ax3.plot(x3, y3, '-r')
ax3.fill_between(x3, y3-err3, y3+err3,alpha=.25, edgecolor='#3F7F4C', facecolor='r',linewidth=0)
## LABEL, marker and errorbar
ax3.errorbar(x3, y3, yerr=err3, fmt='ro', label='')
## Formatting 
#ax3.set_xticks(np.arange(0,24))
ax3.set_xlabel('Year',size=14)
ax3.set_ylabel('Emolecule/cm$^2$',size=14)
#ax3.set_title("Ozone profile",size=16)
#ax3.legend(fontsize=12, loc='upper left')
ax3.tick_params(labelsize=12)

# %%
#identificacion de outliers en periodos de tiempo, eventos extremos, tratar de relacionarlos con temperatura y presion

# %%
smallts
# Out:
#                                   o3column
# time
# 2012-10-26 14:48:33.120000-06:00  6.756701
# 2012-10-26 15:02:13.920000-06:00  6.717759
# 2012-10-26 15:16:56.064000-06:00  6.727473
# 2012-11-16 07:29:04.704000-06:00  6.483526
# 2012-11-16 07:36:58.176000-06:00  6.505157
# ...                                    ...
# 2021-07-24 10:28:47.424000-06:00  7.946076
# 2021-07-24 10:36:13.248000-06:00  7.922451
# 2021-07-24 12:16:50.880000-06:00  7.949151
# 2021-07-24 13:50:19.968000-06:00  7.943056
# 2021-07-24 13:57:46.656000-06:00  7.947200
#
# [4640 rows x 1 columns]

# %%
ds.close()

# %%
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF4):
#     PI_NAME: Grutter;Michel
#     PI_AFFILIATION: Universidad Nacional Autonoma de Mexico;UNAM
#     PI_ADDRESS: Centro de Ciencias de la Atmosfera UNAM;04510 Mexico City;MEXICO
#     PI_EMAIL: grutter@unam.mx
#     DO_NAME: Stremme;Wolfgang
#     DO_AFFILIATION: Universidad Nacional Autonoma de Mexico;UNAM
#     DO_ADDRESS: Centro de Ciencias de la Atmosfera UNAM;04510 Mexico City;MEXICO
#     DO_EMAIL: stremme@atmosfera.unam.mx
#     DS_NAME: Bezanilla;Alejandro
#     DS_AFFILIATION: Universidad Nacional Autonoma de Mexico;UNAM
#     DS_ADDRESS: Centro de Ciencias de la Atmosfera UNAM;04510 Mexico City;MEXICO
#     DS_EMAIL: abezanilla@atmosfera.unam.mx
#     DATA_DESCRIPTION: FTIR vmr vertical profile data of O3 at Altzomoni (Mexico)
#     DATA_DISCIPLINE: ATMOSPHERIC.CHEMISTRY;REMOTE.SENSING;GROUNDBASED
#     DATA_GROUP: EXPERIMENTAL;PROFILE.STATIONARY
#     DATA_LOCATION: ALTZOMONI
#     DATA_SOURCE: FTIR.O3_UNAM001
#     DATA_VARIABLES: DATETIME;LATITUDE.INSTRUMENT;LONGITUDE.INSTRUMENT;ALTITUDE.INSTRUMENT;SURFACE.PRESSURE_INDEPENDENT;SURFACE.TEMPERATURE_INDEPENDENT;ALTITUDE;ALTITUDE.BOUNDARIES;PRESSURE_INDEPENDENT;TEMPERATURE_INDEPENDENT;INTEGRATION.TIME;O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR;O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_APRIORI;O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_AVK;O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_UNCERTAINTY.RANDOM.COVARIANCE;O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_UNCERTAINTY.SYSTEMATIC.COVARIANCE;O3.COLUMN.PARTIAL_ABSORPTION.SOLAR;O3.COLUMN.PARTIAL_ABSORPTION.SOLAR_APRIORI;O3.COLUMN_ABSORPTION.SOLAR;O3.COLUMN_ABSORPTION.SOLAR_APRIORI;O3.COLUMN_ABSORPTION.SOLAR_AVK;O3.COLUMN_ABSORPTION.SOLAR_UNCERTAINTY.RANDOM.STANDARD;O3.COLUMN_ABSORPTION.SOLAR_UNCERTAINTY.SYSTEMATIC.STANDARD;ANGLE.SOLAR_ZENITH.ASTRONOMICAL;ANGLE.SOLAR_AZIMUTH;H2O.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR;H2O.COLUMN_ABSORPTION.SOLAR
#     DATA_START_DATE: 20121026T204833Z
#     DATA_STOP_DATE: 20210724T195746Z
#     DATA_FILE_VERSION: 002
#     DATA_MODIFICATIONS: None
#     DATA_CAVEATS: Data generated within the frame of the Network for the Detection of Atmospheric Composition Change (NDACC)
#     DATA_RULES_OF_USE: contact the PI
#     DATA_ACKNOWLEDGEMENT: Thanks to UNAM for the operation of the instrument, analizing and submission of the data to NDACC. IMK-KIT is acknowledged for the guidence and providing the instrument.
#     DATA_QUALITY: regular cell measurements analysed with Linefit. Reference paper Hase et al., Appl. Opt. 38, 3417-3422, 1999.
#     DATA_TEMPLATE: GEOMS-TE-FTIR-002
#     DATA_PROCESSOR: PROFFIT96
#     FILE_NAME: groundbased_ftir.o3_unam001_altzomoni_20121026t204833z_20210724t195746z_002.hdf
#     FILE_GENERATION_DATE: 20210726T164506Z
#     FILE_ACCESS: NDACC
#     FILE_PROJECT_ID: ------
#     FILE_DOI: ------
#     FILE_ASSOCIATION: NDACC
#     FILE_META_VERSION: 04R043;CUSTOM
#     dimensions(sizes): fakeDim0(41), fakeDim1(2), fakeDim2(41), fakeDim3(1), fakeDim4(4640), fakeDim5(4640), fakeDim6(4640), fakeDim7(4640), fakeDim8(4640), fakeDim9(41), fakeDim10(4640), fakeDim11(1), fakeDim12(1), fakeDim13(4640), fakeDim14(41), fakeDim15(4640), fakeDim16(41), fakeDim17(4640), fakeDim18(4640), fakeDim19(4640), fakeDim20(41), fakeDim21(4640), fakeDim22(4640), fakeDim23(4640), fakeDim24(41), fakeDim25(4640), fakeDim26(41), fakeDim27(4640), fakeDim28(41), fakeDim29(41), fakeDim30(4640), fakeDim31(41), fakeDim32(41), fakeDim33(4640), fakeDim34(41), fakeDim35(41), fakeDim36(4640), fakeDim37(41), fakeDim38(4640), fakeDim39(4640), fakeDim40(4640), fakeDim41(41)
#     variables(dimensions): >f4 ALTITUDE(fakeDim0), >f4 ALTITUDE.BOUNDARIES(fakeDim1,fakeDim2), >f4 ALTITUDE.INSTRUMENT(fakeDim3), >f4 ANGLE.SOLAR_AZIMUTH(fakeDim4), >f4 ANGLE.SOLAR_ZENITH.ASTRONOMICAL(fakeDim5), >f8 DATETIME(fakeDim6), >f4 H2O.COLUMN_ABSORPTION.SOLAR(fakeDim7), >f4 H2O.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR(fakeDim8,fakeDim9), >f4 INTEGRATION.TIME(fakeDim10), >f4 LATITUDE.INSTRUMENT(fakeDim11), >f4 LONGITUDE.INSTRUMENT(fakeDim12), >f4 O3.COLUMN.PARTIAL_ABSORPTION.SOLAR(fakeDim13,fakeDim14), >f4 O3.COLUMN.PARTIAL_ABSORPTION.SOLAR_APRIORI(fakeDim15,fakeDim16), >f4 O3.COLUMN_ABSORPTION.SOLAR(fakeDim17), >f4 O3.COLUMN_ABSORPTION.SOLAR_APRIORI(fakeDim18), >f4 O3.COLUMN_ABSORPTION.SOLAR_AVK(fakeDim19,fakeDim20), >f4 O3.COLUMN_ABSORPTION.SOLAR_UNCERTAINTY.RANDOM.STANDARD(fakeDim21), >f4 O3.COLUMN_ABSORPTION.SOLAR_UNCERTAINTY.SYSTEMATIC.STANDARD(fakeDim22), >f4 O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR(fakeDim23,fakeDim24), >f4 O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_APRIORI(fakeDim25,fakeDim26), >f4 O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_AVK(fakeDim27,fakeDim28,fakeDim29), >f4 O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_UNCERTAINTY.RANDOM.COVARIANCE(fakeDim30,fakeDim31,fakeDim32), >f4 O3.MIXING.RATIO.VOLUME_ABSORPTION.SOLAR_UNCERTAINTY.SYSTEMATIC.COVARIANCE(fakeDim33,fakeDim34,fakeDim35), >f4 PRESSURE_INDEPENDENT(fakeDim36,fakeDim37), >f4 SURFACE.PRESSURE_INDEPENDENT(fakeDim38), >f4 SURFACE.TEMPERATURE_INDEPENDENT(fakeDim39), >f4 TEMPERATURE_INDEPENDENT(fakeDim40,fakeDim41)
#     groups:

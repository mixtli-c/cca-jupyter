# %%
# importamos los paquetes
import numpy as np
import h5py
import glob
import format_co2

# %%
### Esta seccion requiere configuracion por el usuario

# genera la lista de años y el arreglo de meses
years = [2019,2020]          
meses = np.arange(1,13)

# informacion sobre el path de los archivos
readpath = 'f:\\jupyter\\oco3_mexico_city\\h5\\'
readformat = '.h5'

# use read_seedname si los nombres de la fuente tienen un formato establecido, de lo contrario use *
# NOTA: asegurese que el formato generado solo se repita en la seccion de fecha del archivo y no en otro identificador
# (e.g. orbita)
read_seedname = '*'

writepath = 'f:\\jupyter\\oco3_mexico_city\\mexico\\'
write_seedname = 'mexico_oco3_target_'

# yearformat: 0 si es dos digitos, 1 si es 4 digitos

yearformat = 1

### Fin de seccion que requiere configuracion por el usuario

# %%
# testing
for year in years:
    for mes in meses:
        if yearformat == 1:
            filedate = read_seedname + '%i%02i*' % (year,mes)
        else:
            filedate = read_seedname + '%i%02i*' % (year-2000,mes)
        datapath = readpath + filedate + readformat
        print(datapath)
        lista = glob.glob(datapath)
        lista.sort()
        print(lista)
        h5filename = writepath + write_seedname + '%i%02i.h5' % (year,mes)
        print(h5filename)
# Out:
# f:\jupyter\oco3_mexico_city\h5\*201901*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201901.h5
# f:\jupyter\oco3_mexico_city\h5\*201902*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201902.h5
# f:\jupyter\oco3_mexico_city\h5\*201903*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201903.h5
# f:\jupyter\oco3_mexico_city\h5\*201904*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201904.h5
# f:\jupyter\oco3_mexico_city\h5\*201905*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201905.h5
# f:\jupyter\oco3_mexico_city\h5\*201906*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201906.h5
# f:\jupyter\oco3_mexico_city\h5\*201907*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201907.h5
# f:\jupyter\oco3_mexico_city\h5\*201908*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201908.h5
# f:\jupyter\oco3_mexico_city\h5\*201909*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201909.h5
# f:\jupyter\oco3_mexico_city\h5\*201910*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201910.h5
# f:\jupyter\oco3_mexico_city\h5\*201911*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201911.h5
# f:\jupyter\oco3_mexico_city\h5\*201912*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_201912.h5
# f:\jupyter\oco3_mexico_city\h5\*202001*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202001.h5
# f:\jupyter\oco3_mexico_city\h5\*202002*.h5
# ['f:\\jupyter\\oco3_mexico_city\\h5\\04347a_fossil0036_20200208.h5']
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202002.h5
# f:\jupyter\oco3_mexico_city\h5\*202003*.h5
# ['f:\\jupyter\\oco3_mexico_city\\h5\\05078a_fossil0036_20200326.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05139a_fossil0036_20200330.h5']
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202003.h5
# f:\jupyter\oco3_mexico_city\h5\*202004*.h5
# ['f:\\jupyter\\oco3_mexico_city\\h5\\05322a_fossil0036_20200411.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05465a_fossil0036_20200420.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05587a_fossil0036_20200428.h5']
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202004.h5
# f:\jupyter\oco3_mexico_city\h5\*202005*.h5
# ['f:\\jupyter\\oco3_mexico_city\\h5\\05648a_fossil0036_20200502.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05709a_fossil0036_20200506.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05770a_volcano0002_20200510.h5', 'f:\\jupyter\\oco3_mexico_city\\h5\\05992a_fossil0036_20200524.h5']
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202005.h5
# f:\jupyter\oco3_mexico_city\h5\*202006*.h5
# ['f:\\jupyter\\oco3_mexico_city\\h5\\06175a_volcano0002_20200605.h5']
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202006.h5
# f:\jupyter\oco3_mexico_city\h5\*202007*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202007.h5
# f:\jupyter\oco3_mexico_city\h5\*202008*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202008.h5
# f:\jupyter\oco3_mexico_city\h5\*202009*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202009.h5
# f:\jupyter\oco3_mexico_city\h5\*202010*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202010.h5
# f:\jupyter\oco3_mexico_city\h5\*202011*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202011.h5
# f:\jupyter\oco3_mexico_city\h5\*202012*.h5
# []
# f:\jupyter\oco3_mexico_city\mexico\mexico_oco3_target_202012.h5

# %%
# genera la lista de archivos fuente y el nombre del archivo hdf que se creara, llama a la funcion de procesamiento
for year in years:
    for mes in meses:
        if yearformat == 1:
            filedate = read_seedname + '%i%02i*' % (year,mes)
        else:
            filedate = read_seedname + '*%i%02i*' % (year-2000,mes)
        datapath = readpath + filedate + readformat
        lista = glob.glob(datapath)
        lista.sort()
        h5filename = writepath + write_seedname + '%i%02i.h5' % (year,mes)

        if len(lista) != 0:
            format_oco3_target.processlist(lista,h5filename)
            #print len(lista)
        else:
            print("No hay archivos para %i-%02i" % (year,mes))
